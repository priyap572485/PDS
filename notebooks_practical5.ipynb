# %%
import numpy as np
arr = np.array([[4,3,2],[10,2,0],[5,8,24]])
arr
# Out:
# array([[ 4,  3,  2],
#        [10,  2,  0],
#        [ 5,  8, 24]])

# %%
np.amin(arr)
# Out:
# np.int32(0)

# %%
np.amin(arr, axis=0)
# Out:
# array([4, 2, 0])

# %%
np.amin(arr, axis=1)
# Out:
# array([2, 0, 5])

# %%
np.max(arr)
# Out:
# np.int32(24)

# %%
np.amax(arr, axis=0)
# Out:
# array([10,  8, 24])

# %%
np.amax(arr, axis=1)
# Out:
# array([ 4, 10, 24])

# %%
np.median(arr)
# Out:
# np.float64(4.0)

# %%
np.mean(arr)
# Out:
# np.float64(6.444444444444445)

# %%
np.std(arr)
# Out:
# np.float64(6.865551869233515)

# %%
np.var(arr)
# Out:
# np.float64(47.13580246913581)

# %%
np.percentile([0, 30, 45, 60, 90], 50)
# Out:
# np.float64(45.0)

# %%
deg = 90

np.sin(deg * np.pi / 180)
# Out:
# np.float64(1.0)

# %%
np.cos(deg * np.pi / 180)
# Out:
# np.float64(6.123233995736766e-17)

# %%
np.tan(deg * np.pi / 180)
# Out:
# np.float64(1.633123935319537e+16)

# %%
deg * np.pi / 180
# Out:
# 1.5707963267948966

# %%
arr = np.array([0, 1, 0, 8, -2.2, -9, 87])

np.floor(arr)
# Out:
# array([ 0.,  1.,  0.,  8., -3., -9., 87.])

# %%
np.ceil(arr)
# Out:
# array([ 0.,  1.,  0.,  8., -2., -9., 87.])
