# %%
def function_name():
    + + +
    + + +

# %%
def helloworld():
    print("helloworld this is my first function")

# %%
helloworld()
# Out:
# helloworld this is my first function

# %%
def add(x,y):
    return x+y
add(5,4)
# Out:
# 9

# %%
type(helloworld())

# %%
type(None)
# Out:
# NoneType
