# %%
import os
os.listdir()
# Out:
# ['Intro.ipynb',
#  'Sample_File.csv',
#  'Sample_File.csv.ipynb',
#  'Sample_File_json.json',
#  'Untitled.ipynb',
#  'praactical3.ipynb',
#  'practical1.ipynb',
#  'practical2.ipynb',
#  'practical4.ipynb',
#  'practical5.ipynb',
#  'practical6.ipynb',
#  'practical7.ipynb',
#  'practical8.ipynb',
#  'practicals.ipynb',
#  'untitled.py',
#  'untitled1.py',
#  'sqlite.ipynb',
#  'cpp-tiny-ray-tracer.ipynb',
#  'Lorenz.ipynb',
#  'cpp.ipynb',
#  'r.ipynb',
#  'cpp-third-party-libs.ipynb']

# %%
os.getcwd()
# Out:
# '/drive/notebooks'

# %%
import pandas as pimport pandas as pd

df = pd.read_csv('Sample_File.csv')

df.head()
# Out:
#     Name  Age       City
# 0  Rahul   20      Surat
# 1  Priya   21  Ahmedabad
# 2   Amit   22   Vadodara
# 3   Neha   20     Rajkot
# 4  Kiran   23      Surat

# %%
df.iloc[0]
# Out:
# Name    Rahul
# Age        20
# City    Surat
# Name: 0, dtype: object

# %%
df.iloc[4]
# Out:
# Name    Kiran
# Age        23
# City    Surat
# Name: 4, dtype: object

# %%
df.loc[0]
# Out:
# Name    Rahul
# Age        20
# City    Surat
# Name: 0, dtype: object

# %%
df.loc[3]
# Out:
# Name      Neha
# Age         20
# City    Rajkot
# Name: 3, dtype: object

# %%
df.size
# Out:
# 15

# %%
df.memory_usage()
# Out:
# Index    72
# Name     20
# Age      40
# City     20
# dtype: int64

# %%
df.head()
# Out:
#     Name  Age       City
# 0  Rahul   20      Surat
# 1  Priya   21  Ahmedabad
# 2   Amit   22   Vadodara
# 3   Neha   20     Rajkot
# 4  Kiran   23      Surat

# %%
df['Age'] = df['Age'].astype('int32')

# %%
df.size

# %%
df.memory_usage()
# Out:
# Index    72
# Name     20
# Age      40
# City     20
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='str')

# %%
df.groupby('City').mean(numeric_only=True)
# Out:
#             Age
# City
# Ahmedabad  21.0
# Rajkot     20.0
# Surat      21.5
# Vadodara   22.0

# %%
df.groupby('City').max(numeric_only=True)
# Out:
#            Age
# City
# Ahmedabad   21
# Rajkot      20
# Surat       23
# Vadodara    22

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.set_index(['date'],inplace = True)

# %%
df.head()
# Out:
#     Name  Age       City
# 0  Rahul   20      Surat
# 1  Priya   21  Ahmedabad
# 2   Amit   22   Vadodara
# 3   Neha   20     Rajkot
# 4  Kiran   23      Surat

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Rahul', 'Priya', 'Amit', 'Neha', 'Kiran'],
    'Age': [20, 21, 22, 20, 23],
    'City': ['Surat', 'Ahmedabad', 'Vadodara', 'Rajkot', 'Surat'],
    'Date': ['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04', '2026-01-05']
})

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index('Date')

# %%
df.resample('2D').mean(numeric_only=True)
# Out:
#              Age
# Date
# 2026-01-01  20.5
# 2026-01-03  21.0
# 2026-01-05  23.0

# %%
df
# Out:
#              Name  Age       City
# Date
# 2026-01-01  Rahul   20      Surat
# 2026-01-02  Priya   21  Ahmedabad
# 2026-01-03   Amit   22   Vadodara
# 2026-01-04   Neha   20     Rajkot
# 2026-01-05  Kiran   23      Surat

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Sample_File.csv')

df['Age'].plot()
plt.show()

# %%
df = (pd.read_csv('Sample_File.csv')
      .query('city == "Seattle")
             .to_csv('Seattle.csv'))

# %%
df = pd.read_csv('Seattle.csv')

# %%
df.head()
# Out:
#     Name  Age       City
# 0  Rahul   20      Surat
# 1  Priya   21  Ahmedabad
# 2   Amit   22   Vadodara
# 3   Neha   20     Rajkot
# 4  Kiran   23      Surat
