# %%
a = 1
b = 1.0
c = -999

# %%
a = '1'

# %%
type(a)
# Out:
# str

# %%
l = []
l = list()

# %%
l = [1,2,3,4,5]

# %%
l[0]
# Out:
# 1

# %%
l[-1]
# Out:
# 5

# %%
l[2:4]
# Out:
# [3, 4]

# %%
l = [1, 'string', [1, 2, 3]]
print(l)
# Out:
# [1, 'string', [1, 2, 3]]

# %%
print(l)
# Out:
# [1, 'string', [1, 2, 3]]

# %%
for i in l:
    print(i)
# Out:
# 1
# string
# [1, 2, 3]

# %%
for i in range(len(l)):
    print(l[i])
# Out:
# 1
# string
# [1, 2, 3]

# %%
t = ('apple','bottle','car')
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 'apple'

# %%
len(t)
# Out:
# 3

# %%
d = {'a': 1, 'b': 2}

d['a']        
d['b']        

d['c'] = 3    

d             

d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d.key()

# %%
d.values()
# Out:
# dict_values([1, 2])
